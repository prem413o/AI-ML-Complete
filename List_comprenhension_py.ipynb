# %% [markdown]
# <a href="https://colab.research.google.com/github/prem413o/AI-ML-Complete/blob/main/List_comprenhension_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=open("/content/sample_data/text.txt","r")
data=f.read()
print(data)
f.close()
# Out:
# hello my word here is your prem kumar
# come and take your notes pleaseJai shree Ram Jai Shree Ram

# %%
try :
  x=int(input("Enter your number: "))
  ans=10/x
except ZeroDivisionError:
  print("division with 0 is not possible in python")
except ValueError:
  print("the divison with string is not possible")
else:
  print(f"ans is {ans}")
# Out:
# Enter your number: 5
# ans is 2.0

# %%
f=open("/content/sample_data/text.txt","a")
f.write("Jai shree Ram Jai Shree Ram")
f.close()

# %%
square=[]
for i in range(6):
  square.append(i*i)

print(square)

sq=[i*i for i in range(6)]
print(sq)
# Out:
# [0, 1, 4, 9, 16, 25]
# [0, 1, 4, 9, 16, 25]

# %%
nums=[-2,-4,3,5,2,-1]
lim=[0 if val<0 else val for val in nums]
print(lim)
# Out:
# [0, 0, 3, 5, 2, 0]
